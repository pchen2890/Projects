# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
import urllib.request
response = urllib.request.urlopen("https://www.pro-football-reference.com/years/2017/opp.htm")
html = response.read()

# %%
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/pfr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201803061" rel="dns-prefetch"/>
# <!-- no:cookie fast load the css.           -->
# <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
# <link crossorigin="" href="https://d395i9ljze9h3x.cloudfront.net" rel="preconnect"/>
# ...

# %%
table = soup.find_all('table')[0]

# %%
pd.read_html(str(table))[0]
# Out:
#    Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                    Tm                  G
# 0                 1.0     Minnesota Vikings               16.0
# 1                 2.0  Jacksonville Jaguars               16.0
# 2                 3.0  Los Angeles Chargers               16.0
# 3                 4.0   Philadelphia Eagles               16.0
# 4                 5.0  New England Patriots               16.0
# 5                 6.0      Baltimore Ravens               16.0
# 6                 7.0   Pittsburgh Steelers               16.0
# 7                 8.0       Atlanta Falcons               16.0
# 8                 9.0         Chicago Bears               16.0
# 9                10.0    New Orleans Saints               16.0
# 10               11.0     Carolina Panthers               16.0
# 11               12.0      Los Angeles Rams               16.0
# 12               13.0        Dallas Cowboys               16.0
# ...

# %%
d = pd.read_html('https://www.pro-football-reference.com/years/2017/opp.htm')[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-ef622e9730b5> in <module>()
# ----> 1 d = pd.read_html('https://www.pro-football-reference.com/years/2017/opp.htm')[2]
#
# IndexError: list index out of range

# %%
d.tail()
# Out:
#    Unnamed: 0_level_0  Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                  Tm                  G
# 28               29.0      Miami Dolphins               16.0
# 29               30.0  Indianapolis Colts               16.0
# 30               31.0    Cleveland Browns               16.0
# 31               32.0      Houston Texans               16.0
# 32                NaN            Avg Team                NaN
#
#    Unnamed: 3_level_0 Tot Yds & TO Unnamed: 5_level_0 Unnamed: 6_level_0  \
#                    PF          Yds                Ply                Y/P
# 28              393.0       5371.0              989.0                5.4
# 29              404.0       5873.0             1026.0                5.7
# 30              410.0       5250.0             1026.0                5.1
# 31              436.0       5546.0              973.0                5.7
# 32              347.5       5345.0             1013.7                5.3
#
# ...

# %%
# Extract the necessary values for the column headers from the table
# and store them as a list
column_headers = [th.getText() for th in 
                  soup.findAll('tr', limit=2)[1].findAll('th')]

# Add the two additional column headers for the player links
column_headers.extend(["Player_NFL_Link", "Player_NCAA_Link"])b

# %%
# The data is found within the table rows of the element with id=draft
# We want the elements from the 3rd row and on
table_rows = soup.select("#drafts tr")[2:]
